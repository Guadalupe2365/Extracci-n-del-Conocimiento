# %%
import pandas as pd

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\guadalupe\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\guadalupe\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\guadalupe\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\guadalupe\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\guadalupe\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\guadalupe\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
datos = {
    "usuario": ["ana", "pepe", "luis", "rosita", "carolina", "paco"],
    "edad": [14, 22, 35, 40, 62, 70],
    "ciudad": ["cuitlahuac", "yanga", "atoyac", "paraje", "fortin", "cuichapa"],
    "compras_realizadas": [5, 10, 1, 2, 15, 3],
    "activo": [True, True, True, False, True, False],
    "fecha_registro": ["2026-01-10", "2026-05-21", "2026-02-10", "2026-03-11", "2026-04-12", "2026-05-15"]
}

# %%
dfDatos = pd.DataFrame(datos)

# %%
dfDatos
# Out:
#     usuario  edad      ciudad  compras_realizadas  activo fecha_registro
# 0       ana    14  cuitlahuac                   5    True     2026-01-10
# 1      pepe    22       yanga                  10    True     2026-05-21
# 2      luis    35      atoyac                   1    True     2026-02-10
# 3    rosita    40      paraje                   2   False     2026-03-11
# 4  carolina    62      fortin                  15    True     2026-04-12
# 5      paco    70    cuichapa                   3   False     2026-05-15

# %%
cantidad= 1000000

# %%
import random

# %%
#Crear el dataFrame de 1000000 de registros
dfMillon = pd.DataFrame({
    "nombre": [random.choice(dfDatos["usuario"]) for _ in range(cantidad)],
    "edad": [random.randint(18,80) for _ in range(cantidad)],
    "ciudad": [random.choice(dfDatos["ciudad"]) for _ in range(cantidad)],
    "compras_realizadas": [random.randint(1,10) for _ in range(cantidad)],
    "activo":[random.choice(dfDatos["activo"]) for _ in range(cantidad)],
    "fecha_registro": [random.choice(dfDatos["fecha_registro"]) for _ in range(cantidad)]
    
})

# %%
dfMillon.shape
# Out:
# (1000000, 6)

# %%
dfMillon.dtypes
# Out:
# nombre                object
# edad                   int64
# ciudad                object
# compras_realizadas     int64
# activo                  bool
# fecha_registro        object
# dtype: object

# %%
dfMillon.memory_usage(deep=True)
# Out:
# Index                      132
# nombre                53828617
# edad                   8000000
# ciudad                55833133
# compras_realizadas     8000000
# activo                 1000000
# fecha_registro        59000000
# dtype: int64

# %%
dfMillon.memory_usage(deep=True).sum()/1024**2
# Out:
# np.float64(177.06096839904785)
